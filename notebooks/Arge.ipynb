# %%
##

# %% [markdown]
# ## 4 farkli model uzerinden ROC_AUC sonuclari bulunmasi NN , XGBOOST , Logistic Regression

# %% [markdown]
# ## 24 feature feature importnacelara kontrol edilmeli ve onemsiz featurlarin secilmesi .

# %% [markdown]
# ## Catboost with top 5 feature.

# %% [markdown]
# ##
